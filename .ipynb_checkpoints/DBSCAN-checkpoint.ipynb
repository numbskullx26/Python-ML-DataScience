# %% [markdown]
# # Density Based Spatial clustering of Applications with noise

# %% [raw]
# DBSCAN is a robust algorithm to an outlier. It can basically identify the Outliers
#
#
# It should be directly density reachable, sometimes DBSCAN performs better than K means clustering.

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 225751.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 225947.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 230524.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 230656.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 230929.png")

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import matplotlib

# %%
np.random.seed(42)

#function for creating the datapoints in the form of a circle
def PointsInCircum(r,n=100):
    return[(math.cos(2*math.pi/n*x)*r+np.random.normal(-30,30),math.sin(2*math.pi/n*x)*r+np.random.normal(-30,30)) for x in range(1,n+1)]

# %%
#creating data points in the form of a circle 
df = pd.DataFrame(PointsInCircum(500,1000))
df = df.append(PointsInCircum(300,700))
df = df.append(PointsInCircum(100,300))

#adding noise to the dataset

df = df.append([(np.random.randint(-600,600),np.random.randint(-600,600)) for i in range(300)])
# Out:
# C:\Users\Indrajeet Sarkar\AppData\Local\Temp\ipykernel_3044\1655959404.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(PointsInCircum(300,700))
# C:\Users\Indrajeet Sarkar\AppData\Local\Temp\ipykernel_3044\1655959404.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(PointsInCircum(100,300))
# C:\Users\Indrajeet Sarkar\AppData\Local\Temp\ipykernel_3044\1655959404.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append([(np.random.randint(-600,600),np.random.randint(-600,600)) for i in range(300)])

# %%
plt.figure(figsize=(10,10))
plt.scatter(df[0],df[1],s=15,color='grey')
plt.title("Dataset",fontsize=20)
plt.xlabel("Feature 1",fontsize=14)
plt.ylabel("Feature 2",fontsize=14)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Indrajeet Sarkar\\Desktop\\Python-ML\\Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.rename(columns={'Annual Income (k$)':'Income','Spending Score (1-100)':'Spendscore'}, inplace = True)

# %%
df1 = [["Gender","Age"]]

# %%
sns.pairplot(df)

# %%
df = df.drop(['CustomerID'],axis=1)

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Income  Spendscore
# 0           1    Male   19      15          39
# 1           2    Male   21      15          81
# 2           3  Female   20      16           6
# 3           4  Female   23      16          77
# 4           5  Female   31      17          40

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['Age'])
plt.xtricks(rotation=90)
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 3>()
#       1 plt.figure(figsize=(10,5))
#       2 sns.countplot(df['Age'])
# ----> 3 plt.xtricks(rotation=90)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtricks'

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['Income'])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income', ylabel='count'>
