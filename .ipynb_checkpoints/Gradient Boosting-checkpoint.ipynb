# %% [markdown]
# # Gradiant Boosting

# %% [raw]
# The Ensemble method includes two main methods under it :-
#
#     1. Bagging : includes Random Forests and Extra Random Trees. Every decision tree is built parallely.
#     2. Boosting: includes Gradiant Boosting.Every decision tree is built sequentially.
#
#         Boosting technique will always give better results than Bagging technique.

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-23 184630.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-23 184640.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-23 190138.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-23 190452.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-23 190748.png')
