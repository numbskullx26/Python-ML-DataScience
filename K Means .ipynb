# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 114104.png")

# %% [raw]
# Clustering is a technique where we make clusters i.e groups of data.
#
# K Means is a Clustering based algorithm. In K Means clusterinbg, we need to first choose a centroid value for each of the cluster classifications.
#
# Clustering means the assigning of data points to groups based on how similar the points are to each other.

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 114449.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 114800.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 115148.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 115940.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 115947.png")

# %% [markdown]
# # The Elbow Method

# %% [raw]
# The Elbow Method is used to determine the optimal number of clusters in K-Means clustering. The Elbow Method plots the value of the cost function produced by different values of K. The below diagram shows how the elbow method works:-

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 121022.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-25 123501.png")
