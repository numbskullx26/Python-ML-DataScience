# %% [raw]
# There are two types of Regression:
# 1. Linear Regression : used to predict continuous outcomes. Numerical values, for eg. Weather for the next month, Revenue of the Company by the end of the year. It maily includes and uses Continuous values: 23,4,5,6,6 or 1,2,3,4,5
#
# 2. Logistical Regression : is used to basically solve classification based problems. It includes and uses Categorial Values: 'Delhi','Mumbai','India'ble.
#
#
# Linear Regression Formula:-
#
# Y(dependent variable) = mx(independent variable) + c. This tells you the relationship between two values (dependent and independent). In regression, we find the best fit line only throughout/around the data points.
#
# Dependent variable should always be continuous
#
# Linear Regression is used to predict the continuous dependent variable using a given set of independent variables.
# Logistic Regression is used to predict the categorial dependent variable using a given set of independent variables.
#
# Single Linear Regression : y=mx+c
# Multiple Linear Regression : y=m1x + m2x + m3x + .... + c

# %% [markdown]
# # Linear Regression

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-29 235640.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-30 000708.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-30 001513.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-30 001533.png")

# %% [markdown]
# # Logistic Regression

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-30 001627.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-30 001832.png")

# %% [raw]
# # The above given is the formula for Logistic Regression. Here -z = mx+c.
#
# Y is the middle of the Y-axis is called the Threashold value and it lies in the middle. Suppose if the predicted value is more than 0.5, it will be rounded off to Y=1 and the answer will be yes(1). Eg. Pass
#
# Suppose if the predicted value is less than 0.5, it will be rounded off to Y=0 and the answer will be no(0) Eg. fail. Hence on the basis of this, we solve a Classification problem.
#
# The value of logistic regression always lies in between 0s and 1s.

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-30 002851.png")

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-01-30 002858.png")

# %% [raw]
# The value of Logistic regression is called a Sigmoid.
# Decision Bound is basically the threashold point.

# %% [raw]
# In simple terms, logistic regression(the formula of logistic) converts the independent variable expression of probability that ranges between 0 and 1 with respect to the independent variable

# %% [markdown]
# # Problem Statement

# %%
import numpy as np
import pandas as pd

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
advertising = pd.read_csv("C:\\Users\\Indrajeet Sarkar\\Desktop\\Python Data Science\\advertising.csv")
advertising.head()
# Out:
#    Index     TV  Newspaper  Sales
# 0      0  230.1       69.2   22.1
# 1      1   44.5       45.1   10.4
# 2      2   17.2       69.3   12.0
# 3      3  151.5       58.5   16.5
# 4      4  180.8       58.4   17.9

# %%
advertising.shape
# Out:
# (5, 4)

# %%
advertising.info
# Out:
# <bound method DataFrame.info of    Index     TV  Newspaper  Sales
# 0      0  230.1       69.2   22.1
# 1      1   44.5       45.1   10.4
# 2      2   17.2       69.3   12.0
# 3      3  151.5       58.5   16.5
# 4      4  180.8       58.4   17.9>

# %%
advertising.describe()
# Out:
#           Index         TV  Newspaper      Sales
# count  5.000000    5.00000   5.000000   5.000000
# mean   2.000000  124.82000  60.100000  15.780000
# std    1.581139   90.77834   9.973715   4.695423
# min    0.000000   17.20000  45.100000  10.400000
# 25%    1.000000   44.50000  58.400000  12.000000
# 50%    2.000000  151.50000  58.500000  16.500000
# 75%    3.000000  180.80000  69.200000  17.900000
# max    4.000000  230.10000  69.300000  22.100000

# %%
advertising.isnull() #will show if there are any null values in any of the rows and columns
# Out:
#    Index     TV  Newspaper  Sales
# 0  False  False      False  False
# 1  False  False      False  False
# 2  False  False      False  False
# 3  False  False      False  False
# 4  False  False      False  False

# %%
advertising.isnull().sum() #will give us the sum of null values of each column
# Out:
# Index        0
# TV           0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
advertising.shape[0]
# Out:
# 5

# %%
#checking null values
advertising.isnull().sum()*100/advertising.shape[0] #convertising the sum of null values of each column to percentage by multiplying by 100
#There are nop null values and hence it is clean
# Out:
# Index        0.0
# TV           0.0
# Newspaper    0.0
# Sales        0.0
# dtype: float64

# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
advertising = pd.read_csv("C:\\Users\\Indrajeet Sarkar\\Desktop\\Python-ML\\advertising.csv")
advertising.head()
# Out:
#    Index     TV  Newspaper  Sales
# 0      0  230.1       69.2   22.1
# 1      1   44.5       45.1   10.4
# 2      2   17.2       69.3   12.0
# 3      3  151.5       58.5   16.5
# 4      4  180.8       58.4   17.9

# %%
#outlier analysis 
fig, axs = plt.subplots(3,figsize=(10,10))
plt1 = sns.boxplot(advertising['TV'],ax=axs[0])
plt2 = sns.boxplot(advertising['Newspaper'], ax=axs[1])
plt3 = sns.boxplot(advertising['Sales'],ax=axs[2])
plt.tight_layout()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,6.948 + 0.034 * x_test, 'r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 plt.scatter(x_test,y_test)
#       2 plt.plot(x_test,6.948 + 0.034 * x_test, 'r')
#       3 plt.show()
#
# NameError: name 'x_test' is not defined
