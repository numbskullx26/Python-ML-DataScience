# %% [raw]
# A decision tree is a graphical representation of all the possible solutions to a decision based on certain conditions.

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-21 232723.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-21 233558.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-21 234052.png")

# %% [raw]
# Decision tree terminology
#
# In a decision tree algorithm, there is a tree like structure in which each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label. The paths from the root node reprensent classification rules.
#
# The terminologies used in Decision trees include:-

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-21 234559.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-21 234712.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-21 234858.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-21 235340.png")

# %%
#Entropy will tell us the purity of split
# IG will tell us the Quality of a split

# %% [raw]
# Entropy
#
# Entropy measures the impurity in the given dataset

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-22 010614.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-22 010641.png")

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-22 121149.png")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df  = pd.read_csv("C:\\Users\\Indrajeet Sarkar\\Desktop\\Python-ML\\car_evaluation.csv", header =  None)

# %%
df.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %%
df.shape
# Out:
# (1728, 7)

# %%
for i in df['doors']:
    print(i+'2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File E:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File E:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'doors'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 for i in df['doors']:
#       2     print(i+'2')
#
# ...

# %%
col_names = ['buying','maint','doors','persons','lug_boot','safety','class'] #changing the column names
df.columns=col_names
col_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
df['buying'].value_counts()
# Out:
# vhigh    432
# high     432
# med      432
# low      432
# Name: buying, dtype: int64

# %%
df['buying']
# Out:
# 0       vhigh
# 1       vhigh
# 2       vhigh
# 3       vhigh
# 4       vhigh
#         ...
# 1723      low
# 1724      low
# 1725      low
# 1726      low
# 1727      low
# Name: buying, Length: 1728, dtype: object

# %%
df['buying'].apply(lambda x:x+'1')
# Out:
# 0       vhigh1
# 1       vhigh1
# 2       vhigh1
# 3       vhigh1
# 4       vhigh1
#          ...
# 1723      low1
# 1724      low1
# 1725      low1
# 1726      low1
# 1727      low1
# Name: buying, Length: 1728, dtype: object

# %%
for j in col_names:
    print(j+'1')
# Out:
# buying1
# maint1
# doors1
# persons1
# lug_boot1
# safety1
# class1

# %%
df['doors'].value_counts()
# Out:
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: doors, dtype: int64

# %%
for col in col_names:
    print(df[col].value_counts())
# Out:
# vhigh    432
# high     432
# med      432
# low      432
# Name: buying, dtype: int64
# vhigh    432
# high     432
# med      432
# low      432
# Name: maint, dtype: int64
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: doors, dtype: int64
# 2       576
# 4       576
# more    576
# Name: persons, dtype: int64
# small    576
# med      576
# big      576
# Name: lug_boot, dtype: int64
# low     576
# med     576
# high    576
# Name: safety, dtype: int64
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64

# %%
df['class'].value_counts()
# Out:
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64
